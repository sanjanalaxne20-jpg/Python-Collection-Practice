# %%
#print string
s1='''pune is 
clean city'''

# %%
s1
# Out:
# 'pune is \nclean city'

# %%
#type() returns the data type of the given value.
print(type('hello'))
# Out:
# <class 'str'>

# %%
a='hello'

# %%
a[-1]#print last item in the string
# Out:
# 'o'

# %%
a[2]#print item using index function
# Out:
# 'l'

# %%
del a[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del a[2]
#
# TypeError: 'str' object doesn't support item deletion

# %%
a[-2]
# Out:
# 'l'

# %%
a[2] = 0 #string object does not support assignment operator
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 a[2] = 0
#
# TypeError: 'str' object does not support item assignment

# %%
del a[2] #string does not support deletion
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 del a[2]
#
# TypeError: 'str' object doesn't support item deletion

# %%
"HELLO".lower()#print the lowercase of the string
# Out:
# 'hello'

# %%
"hello".upper()#print the uppercase of the string
# Out:
# 'HELLO'

# %%
"hello world".title()#first letter capital of each word
# Out:
# 'Hello World'

# %%
"hello".capitalize()#capitalize the word
# Out:
# 'Hello'

# %%
" hi ".strip()#remove the spacing
# Out:
# 'hi'

# %%
" hi".lstrip()#remove the left spacing
# Out:
# 'hi'

# %%
"hi ".rstrip()#remove the right spacing
# Out:
# 'hi'

# %%
"apple".replace("p","b")#replace the word
# Out:
# 'abble'

# %%
"a,b,c".split(",")#split(",") divides the string into a list using a comma as the separator.
# Out:
# ['a', 'b', 'c']

# %%
"-".join(['a','b','c'])#joining the string
# Out:
# 'a-b-c'

# %%
"hello".find("e")#finding the value in the string
# Out:
# 1

# %%
"hello".index("e")#find the index
# Out:
# 1

# %%
"banana".count("a")#how many times repeat the word
# Out:
# 3

# %%
"hello" .startswith("he")#cheack the value start with in the string
# Out:
# True

# %%
"hello".endswith("lo")#cheack the value end with given in the string
# Out:
# True

# %%
"hello" .startswith("te")
# Out:
# False

# %%
"hello".endswith("se")
# Out:
# False

# %%
"abc".isalpha()#check string is an albhabet
# Out:
# True

# %%
"123".isdigit()#check string is an integer
# Out:
# True

# %%
"abc123".isalnum()#check the string is an alpha numeric
# Out:
# True

# %%
"1abc".isalpha()
# Out:
# False

# %%
"1b23".isdigit()
# Out:
# False

# %%
len("Pune")#check the length of thr string
# Out:
# 4

# %%
sorted("pune")#sorted in alphabetical oredr
# Out:
# ['e', 'n', 'p', 'u']

# %%
list("hello")#separeted by list
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
"".join(sorted("pune"))#join the alphabetical oredr
# Out:
# 'enpu'
