# %%
l1=[1,2,3,4,5,6]#list perform homogenious (all elements are displyaed
print(L1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1.append(40)#inserting the values at the end
l1
# Out:
# [1, 2, 3, 4, 5, 6, 40]

# %%
l1.append(30,40)#only one argument take
l1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 l1.append(30,40)
#       2 l1
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
l1.insert(6,100)#insert the value in list
l1
# Out:
# [1, 100, 2, 3, 100, 100, 100, 100, 4, 5, 6, 40]

# %%
l1.insert(4,200,300)
l1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 l1.insert(4,200,300)
#       2 l1
#
# TypeError: insert expected 2 arguments, got 3

# %%
l1.insert(30,40)
l1
# Out:
# [1, 100, 2, 3, 100, 100, 100, 100, 4, 5, 6, 40, 40]

# %%
print(type(List))
# Out:
# <class 'list'>

# %%
l1[4]
# Out:
# 100

# %%
l1[0:5:2]
# Out:
# [1, 2, 100]

# %%
l1[]# invalid syntax
# Out:
#   Cell In[27], line 1
#     l1[]# invalid syntax
#        ^
# SyntaxError: invalid syntax

# %%
l1.insert(5,[100,700,900])
l1
# Out:
# [1, 100, 2, 3, 100, [100, 700, 900], 100, 100, 100, 4, 5, 6, 40, 40]

# %%
l1.pop()
l1
# Out:
# [1, 100, 2, 3, 100, [100, 700, 900], 100, 100, 100, 4, 5, 6, 40, 40, 2500]

# %%
l1[::]
l1
# Out:
# [1, 100, 2, 3, 100, 100, 100, 100, 4, 5, 6, 40, 40, 2500]

# %%
l1.pop(5)#remove the last value
l1
# Out:
# [1, 100, 2, 3, 100, 100, 100, 100, 4, 5, 6, 40, 40, 2500]

# %%
l1.remove(2500)
l1
# Out:
# [1, 100, 2, 3, 100, 100, 100, 100, 4, 5, 6, 40, 40]

# %%
l1.remove(1,3)#only one argument remove at one time
l1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 l1.remove(1,3)
#       2 l1
#
# TypeError: list.remove() takes exactly one argument (2 given)

# %%
len(l1)#cunt total number of element in list
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
all(l1)#check all numbers are non zero
# Out:
# True

# %%
l1.clear()#clear all the element
l1
# Out:
# []

# %%
l1=[1,2,3,4,5]#print all the element
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l1[:]#print all element of the list
# Out:
# [1, 2, 3, 4, 5]

# %%
l1[::]#print entire element of the list
# Out:
# [1, 2, 3, 4, 5]

# %%
l1[::4]#print every 4th element of the list
# Out:
# [1, 5]

# %%
l1=[1,2,3,4,5]
print(any(l1))
# Out:
# True

# %%
l1=[1,2,3,4,5]#finding the lenth using leg()function
print(len(l1))
# Out:
# 5

# %%
sorted(l1,reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
sorted(l1,reverse=-1)
# Out:
# [5, 4, 3, 2, 1]
